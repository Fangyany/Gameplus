# %%
import pandas as pd
import matplotlib.pyplot as plt
# import seaborn as sns
# sns.set()
plt.rcParams['font.sans-serif'] = ['Noto Sans CJK JP']

def plot_loss(ax, loss_name, key, label_i):
    loss_data = pd.read_csv(f'training_log/Exp_{loss_name}_nuplan/train_log.csv')
    loss = loss_data[key][:50]
    ax.plot(loss, label=f'{label_i}')
    
    ax.tick_params(axis='both', labelsize=14)  # 设置XY轴刻度数字的大小
    ax.legend(fontsize=14)

keys = ['val-planningADE', 'val-planningFDE', 'val-planningAHE', 
        'val-planningFHE', 'val-predictionADE', 'val-predictionFDE']

y_label = ['规划轨迹平均位移误差', '规划轨迹终点位移误差', '规划轨迹平均朝向误差', '规划轨迹终点朝向误差', '预测轨迹平均位移误差', '预测轨迹终点位移误差']
# label = ['Dual-Net', 'Dual-Fusion-Net']
# label = ['策略1', '策略2', '策略3']
fig, axes = plt.subplots(3, 2, figsize=(15, 15))  # Adjust the size as needed
axes = axes.flatten()  # Flatten the array to make indexing easier

for i, key in enumerate(keys):
    ax = axes[i]
    # for j, loss_name in enumerate(['dual', 'fusion', 'add']):
    #     plot_loss(ax, loss_name, key, label[j])
    
    # Plot baseline
    loss_data = pd.read_csv('training_log/Exp_pre_nuplan/train_log.csv')
    loss = loss_data[key]
    ax.plot(loss[:50], label='Baseline')
    ax.legend(fontsize=14)
    ax.tick_params(axis='both', labelsize=14) 
    
    # Plot dual-net
    loss_data = pd.read_csv('training_log/Exp_dual_nuplan/train_log.csv')
    loss = loss_data[key][:50]
    ax.plot(loss, label='Dual-Net')
    ax.legend(fontsize=14)
    ax.tick_params(axis='both', labelsize=14) 
    

    # Plot ours 
    loss_data = pd.read_csv('training_log/Exp_div_nuplan/train_log.csv')
    loss = loss_data[key]
    ax.plot(loss[:50], label='Fusion-Net')
    ax.legend(fontsize=14)
    ax.tick_params(axis='both', labelsize=14) 
    
    
    # ax.axis('equal')
    ax.set_ylabel(f'{y_label[i]}', fontsize=18)
    ax.set_xlabel('迭代次数', fontsize=18)
    ax.grid(True, linestyle='--', alpha=0.7)


plt.tight_layout()
plt.savefig('fig/三种网络.pdf', format='pdf', dpi=300)
# plt.savefig('fig/层次动态特征融合对比试验.pdf', format='pdf', dpi=300)

# %%
import pandas as pd
import matplotlib.pyplot as plt
# import seaborn as sns
# sns.set()
plt.rcParams['font.sans-serif'] = ['Noto Sans CJK JP']

keys = ['val-planningADE', 'val-planningFDE', 'val-planningAHE', 
        'val-planningFHE', 'val-predictionADE', 'val-predictionFDE']

y_label = ['规划轨迹平均位移误差', '规划轨迹终点位移误差', '规划轨迹平均朝向误差',
           '规划轨迹终点朝向误差', '预测轨迹平均位移误差', '预测轨迹终点位移误差']

fig, axes = plt.subplots(3, 2, figsize=(15, 15))  # Adjust the size as needed
axes = axes.flatten()  # Flatten the array to make indexing easier

for i, key in enumerate(keys):
    ax = axes[i]
    
    # Plot top level
    loss_data = pd.read_csv('training_log/Exp_dual_nuplan/train_log.csv')
    loss = loss_data[key][:30]
    ax.plot(loss, label='策略1')
    
    # Plot add
    loss_data = pd.read_csv('training_log/Exp_add_nuplan/train_log.csv')
    loss = loss_data[key][:30]
    ax.plot(loss, label='策略2')

    # Plot att mean
    loss_data = pd.read_csv('training_log/Exp_fusion_nuplan/train_log.csv')
    loss = loss_data[key][:30]
    ax.plot(loss, label='策略3')
    
    # Plot att add
    loss_data = pd.read_csv('training_log/Exp_fusion_attadd_nuplan/train_log.csv')
    loss = loss_data[key][:30]
    ax.plot(loss, label='策略4')
    
    # Plot multi
    loss_data = pd.read_csv('training_log/Exp_fusion_multi_nuplan/train_log.csv')
    loss = loss_data[key][:30]
    ax.plot(loss, label='策略5')
    
    # ax.axis('equal')
    ax.set_ylabel(f'{y_label[i]}', fontsize=18)
    ax.set_xlabel('迭代次数', fontsize=18)
    ax.legend(fontsize=14)
    ax.tick_params(axis='both', labelsize=14) 
    ax.grid(True, linestyle='--', alpha=0.7)

plt.tight_layout()
# plt.savefig('fig/三种网络.pdf', format='pdf', dpi=300)
plt.savefig('fig/层次动态特征融合对比试验.pdf', format='pdf', dpi=300)

# %%
import pandas as pd
import matplotlib.pyplot as plt
# import seaborn as sns
# sns.set()
plt.rcParams['font.sans-serif'] = ['Noto Sans CJK JP']

keys = ['val-planningADE', 'val-planningFDE', 'val-planningAHE', 
        'val-planningFHE', 'val-predictionADE', 'val-predictionFDE']

y_label = ['规划轨迹平均位移误差', '规划轨迹终点位移误差', '规划轨迹平均朝向误差',
           '规划轨迹终点朝向误差', '预测轨迹平均位移误差', '预测轨迹终点位移误差']

fig, axes = plt.subplots(3, 2, figsize=(15, 15))  # Adjust the size as needed
axes = axes.flatten()  # Flatten the array to make indexing easier

for i, key in enumerate(keys):
    ax = axes[i]
    
    # Plot top level
    loss_data = pd.read_csv('training_log/Exp_dual_nuplan/train_log.csv')
    loss = loss_data[key]
    ax.plot(loss, label='最高层')
    
    # Plot add
    loss_data = pd.read_csv('training_log/Exp_add_nuplan/train_log.csv')
    loss = loss_data[key]
    ax.plot(loss, label='Add')

    # Plot att mean
    loss_data = pd.read_csv('training_log/Exp_fusion_nuplan/train_log.csv')
    loss = loss_data[key]
    ax.plot(loss, label='att mean')
    
    # Plot att add
    loss_data = pd.read_csv('training_log/Exp_fusion_attadd_nuplan/train_log.csv')
    loss = loss_data[key]
    ax.plot(loss, label='att add')
    
    # Plot multi
    loss_data = pd.read_csv('training_log/Exp_fusion_multi_nuplan/train_log.csv')
    loss = loss_data[key]
    ax.plot(loss, label='multi')
    
    # ax.axis('equal')
    ax.set_ylabel(f'{y_label[i]}', fontsize=18)
    ax.set_xlabel('迭代次数', fontsize=18)
    ax.legend(fontsize=14)
    ax.tick_params(axis='both', labelsize=14) 
    ax.grid(True, linestyle='--', alpha=0.7)

plt.tight_layout()
# plt.savefig('fig/三种网络.pdf', format='pdf', dpi=300)
plt.savefig('fig/层次动态特征融合对比试验.pdf', format='pdf', dpi=300)

# %%
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
# sns.set()

# def plot_loss(loss_name, key):
#     loss_data = pd.read_csv(f'training_log/Exp_{loss_name}_nuplan/train_log.csv') 
#     loss = loss_data[key]
#     plt.plot(loss, label=f'method_{loss_name}')
#     plt.legend()
#     # return loss

# for key in ['val-planningADE', 'val-planningFDE', 'val-planningAHE', 
#             'val-planningFHE', 'val-predictionADE', 'val-predictionFDE']:
   
#     plt.rcParams['figure.figsize'] = (5, 5)
#     for loss_name in ['dual', 'fusion', 'add']:
#         plot_loss(loss_name, key)
        
#     loss_data = pd.read_csv('training_log/Exp_pre_nuplan/train_log.csv') 
#     loss = loss_data[key]
#     plt.plot(loss, label='Baseline')

#     plt.legend()
#     plt.ylabel(f'{key}')
#     plt.xlabel('Iteration Number')

#     plt.show()

# # plt.savefig('fig/pred_loss.eps', format='eps', dpi=300)
